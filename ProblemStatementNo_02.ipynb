# %% [markdown]
# <a href="https://colab.research.google.com/github/KadamShivanjalii/OIBSIP_DataScience_Task1/blob/main/ProblemStatementNo_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(869)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.select_dtypes(include=['object','category']).columns
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
df[['sex','embarked','who']].describe()
# Out:
#          sex embarked  who
# count    891      889  891
# unique     2        3    3
# top     male        S  man
# freq     577      644  537

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.shape
# Out:
# (891, 15)

# %%
df['pclass']=df['pclass'].astype('category')

# %%
df['age']=df['age'].astype('category')

# %%
df.dtypes
# Out:
# survived          int64
# pclass         category
# sex              object
# age            category
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['parch']=df['parch'].astype('float64')

# %%
df[['survived','sibsp']]=df[['survived','sibsp']].astype('category')

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
numcol=df.select_dtypes(include=np.number).columns
numcol

df[numcol]=sc.fit_transform(df[numcol])
df.head()
# Out:
#   survived pclass     sex   age sibsp  parch      fare embarked  class    who  \
# 0        0      3    male  22.0     1    0.0  0.014151        S  Third    man
# 1        1      1  female  38.0     1    0.0  0.139136        C  First  woman
# 2        1      3  female  26.0     0    0.0  0.015469        S  Third  woman
# 3        1      1  female  35.0     1    0.0  0.103644        S  First  woman
# 4        0      3    male  35.0     0    0.0  0.015713        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True
